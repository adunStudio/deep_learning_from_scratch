# %%
# coding: utf-8
import sys
sys.path.append('..')
import numpy as np
import matplotlib.pyplot as plt
from dataset import sequence
from common.optimizer import Adam
from common.trainer import Trainer
from common.util import eval_seq2seq
from seq2seq import Seq2seq
#from peeky_seq2seq import PeekySeq2seq


# 데이터셋 읽기
(x_train, t_train), (x_test, t_test) = sequence.load_data('addition.txt')
char_to_id, id_to_char = sequence.get_vocab()

# 입력 반전 여부 설정 =============================================
is_reverse = False  # True
if is_reverse:
    x_train, x_test = x_train[:, ::-1], x_test[:, ::-1]
# ================================================================

# 하이퍼파라미터 설정
vocab_size = len(char_to_id)
wordvec_size = 16
hidden_size = 128
batch_size = 128
max_epoch = 25
max_grad = 5.0

# 일반 혹은 엿보기(Peeky) 설정 =====================================
model = Seq2seq(vocab_size, wordvec_size, hidden_size)
# model = PeekySeq2seq(vocab_size, wordvec_size, hidden_size)
# ================================================================
optimizer = Adam()
trainer = Trainer(model, optimizer)

acc_list = []
for epoch in range(max_epoch):
    trainer.fit(x_train, t_train, max_epoch=1,
                batch_size=batch_size, max_grad=max_grad)

    correct_num = 0
    for i in range(len(x_test)):
        question, correct = x_test[[i]], t_test[[i]]
        verbose = i < 10
        correct_num += eval_seq2seq(model, question, correct,
                                    id_to_char, verbose, is_reverse)

    acc = float(correct_num) / len(x_test)
    acc_list.append(acc)
    print('검증 정확도 %.3f%%' % (acc * 100))

# 그래프 그리기
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('에폭')
plt.ylabel('정확도')
plt.ylim(0, 1.0)
plt.show()
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 2.56
# | 에폭 1 |  반복 21 / 351 | 시간 0[s] | 손실 2.53
# | 에폭 1 |  반복 41 / 351 | 시간 1[s] | 손실 2.17
# | 에폭 1 |  반복 61 / 351 | 시간 1[s] | 손실 1.96
# | 에폭 1 |  반복 81 / 351 | 시간 1[s] | 손실 1.92
# | 에폭 1 |  반복 101 / 351 | 시간 2[s] | 손실 1.87
# | 에폭 1 |  반복 121 / 351 | 시간 2[s] | 손실 1.85
# | 에폭 1 |  반복 141 / 351 | 시간 3[s] | 손실 1.83
# | 에폭 1 |  반복 161 / 351 | 시간 3[s] | 손실 1.79
# | 에폭 1 |  반복 181 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 201 / 351 | 시간 4[s] | 손실 1.77
# | 에폭 1 |  반복 221 / 351 | 시간 4[s] | 손실 1.76
# | 에폭 1 |  반복 241 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 261 / 351 | 시간 5[s] | 손실 1.76
# | 에폭 1 |  반복 281 / 351 | 시간 5[s] | 손실 1.75
# | 에폭 1 |  반복 301 / 351 | 시간 6[s] | 손실 1.74
# | 에폭 1 |  반복 321 / 351 | 시간 6[s] | 손실 1.75
# | 에폭 1 |  반복 341 / 351 | 시간 7[s] | 손실 1.74
# Q 77+85
# T 162
# ☒ 100
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 1000
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 1000
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1000
# ---
# Q 26+838
# T 864
# ☒ 1000
# ---
# Q 143+93
# T 236
# ☒ 100
# ---
# 검증 정확도 0.180%
# | 에폭 2 |  반복 1 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 21 / 351 | 시간 0[s] | 손실 1.73
# | 에폭 2 |  반복 41 / 351 | 시간 0[s] | 손실 1.74
# | 에폭 2 |  반복 61 / 351 | 시간 1[s] | 손실 1.74
# | 에폭 2 |  반복 81 / 351 | 시간 1[s] | 손실 1.73
# | 에폭 2 |  반복 101 / 351 | 시간 2[s] | 손실 1.73
# | 에폭 2 |  반복 121 / 351 | 시간 2[s] | 손실 1.72
# | 에폭 2 |  반복 141 / 351 | 시간 3[s] | 손실 1.71
# | 에폭 2 |  반복 161 / 351 | 시간 3[s] | 손실 1.71
# | 에폭 2 |  반복 181 / 351 | 시간 5[s] | 손실 1.71
# | 에폭 2 |  반복 201 / 351 | 시간 6[s] | 손실 1.70
# | 에폭 2 |  반복 221 / 351 | 시간 7[s] | 손실 1.71
# | 에폭 2 |  반복 241 / 351 | 시간 7[s] | 손실 1.70
# | 에폭 2 |  반복 261 / 351 | 시간 8[s] | 손실 1.69
# | 에폭 2 |  반복 281 / 351 | 시간 8[s] | 손실 1.69
# | 에폭 2 |  반복 301 / 351 | 시간 9[s] | 손실 1.69
# | 에폭 2 |  반복 321 / 351 | 시간 9[s] | 손실 1.68
# | 에폭 2 |  반복 341 / 351 | 시간 10[s] | 손실 1.67
# Q 77+85
# T 162
# ☒ 994
# ---
# Q 975+164
# T 1139
# ☒ 1000
# ---
# Q 582+84
# T 666
# ☒ 700
# ---
# Q 8+155
# T 163
# ☒ 100
# ---
# Q 367+55
# T 422
# ☒ 400
# ---
# Q 600+257
# T 857
# ☒ 1000
# ---
# Q 761+292
# T 1053
# ☒ 1000
# ---
# Q 830+597
# T 1427
# ☒ 1544
# ---
# Q 26+838
# T 864
# ☒ 400
# ---
# Q 143+93
# T 236
# ☒ 400
# ---
# 검증 정확도 0.220%
# | 에폭 3 |  반복 1 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 21 / 351 | 시간 0[s] | 손실 1.66
# | 에폭 3 |  반복 41 / 351 | 시간 1[s] | 손실 1.65
# | 에폭 3 |  반복 61 / 351 | 시간 1[s] | 손실 1.63
# | 에폭 3 |  반복 81 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 101 / 351 | 시간 2[s] | 손실 1.62
# | 에폭 3 |  반복 121 / 351 | 시간 3[s] | 손실 1.60
# | 에폭 3 |  반복 141 / 351 | 시간 4[s] | 손실 1.59
# | 에폭 3 |  반복 161 / 351 | 시간 4[s] | 손실 1.57
# | 에폭 3 |  반복 181 / 351 | 시간 5[s] | 손실 1.57
# | 에폭 3 |  반복 201 / 351 | 시간 5[s] | 손실 1.56
# | 에폭 3 |  반복 221 / 351 | 시간 6[s] | 손실 1.54
# | 에폭 3 |  반복 241 / 351 | 시간 6[s] | 손실 1.52
# | 에폭 3 |  반복 261 / 351 | 시간 7[s] | 손실 1.52
# | 에폭 3 |  반복 281 / 351 | 시간 7[s] | 손실 1.52
# | 에폭 3 |  반복 301 / 351 | 시간 8[s] | 손실 1.50
# | 에폭 3 |  반복 321 / 351 | 시간 8[s] | 손실 1.49
# | 에폭 3 |  반복 341 / 351 | 시간 9[s] | 손실 1.48
# Q 77+85
# T 162
# ☒ 108
# ---
# Q 975+164
# T 1139
# ☒ 1001
# ---
# Q 582+84
# T 666
# ☒ 648
# ---
# Q 8+155
# T 163
# ☒ 138
# ---
# Q 367+55
# T 422
# ☒ 448
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1373
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 348
# ---
# 검증 정확도 0.560%
# | 에폭 4 |  반복 1 / 351 | 시간 0[s] | 손실 1.47
# | 에폭 4 |  반복 21 / 351 | 시간 0[s] | 손실 1.46
# | 에폭 4 |  반복 41 / 351 | 시간 0[s] | 손실 1.44
# | 에폭 4 |  반복 61 / 351 | 시간 1[s] | 손실 1.43
# | 에폭 4 |  반복 81 / 351 | 시간 1[s] | 손실 1.42
# | 에폭 4 |  반복 101 / 351 | 시간 2[s] | 손실 1.41
# | 에폭 4 |  반복 121 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 4 |  반복 141 / 351 | 시간 3[s] | 손실 1.40
# | 에폭 4 |  반복 161 / 351 | 시간 4[s] | 손실 1.38
# | 에폭 4 |  반복 181 / 351 | 시간 4[s] | 손실 1.38
# | 에폭 4 |  반복 201 / 351 | 시간 4[s] | 손실 1.37
# | 에폭 4 |  반복 221 / 351 | 시간 5[s] | 손실 1.35
# | 에폭 4 |  반복 241 / 351 | 시간 6[s] | 손실 1.33
# | 에폭 4 |  반복 261 / 351 | 시간 8[s] | 손실 1.33
# | 에폭 4 |  반복 281 / 351 | 시간 8[s] | 손실 1.33
# | 에폭 4 |  반복 301 / 351 | 시간 9[s] | 손실 1.32
# | 에폭 4 |  반복 321 / 351 | 시간 9[s] | 손실 1.31
# | 에폭 4 |  반복 341 / 351 | 시간 10[s] | 손실 1.30
# Q 77+85
# T 162
# ☒ 146
# ---
# Q 975+164
# T 1139
# ☒ 1189
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 432
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1002
# ---
# Q 830+597
# T 1427
# ☒ 1406
# ---
# Q 26+838
# T 864
# ☒ 862
# ---
# Q 143+93
# T 236
# ☒ 202
# ---
# 검증 정확도 1.060%
# | 에폭 5 |  반복 1 / 351 | 시간 0[s] | 손실 1.28
# | 에폭 5 |  반복 21 / 351 | 시간 0[s] | 손실 1.29
# | 에폭 5 |  반복 41 / 351 | 시간 1[s] | 손실 1.28
# | 에폭 5 |  반복 61 / 351 | 시간 2[s] | 손실 1.27
# | 에폭 5 |  반복 81 / 351 | 시간 3[s] | 손실 1.27
# | 에폭 5 |  반복 101 / 351 | 시간 4[s] | 손실 1.26
# | 에폭 5 |  반복 121 / 351 | 시간 4[s] | 손실 1.26
# | 에폭 5 |  반복 141 / 351 | 시간 5[s] | 손실 1.27
# | 에폭 5 |  반복 161 / 351 | 시간 5[s] | 손실 1.26
# | 에폭 5 |  반복 181 / 351 | 시간 6[s] | 손실 1.25
# | 에폭 5 |  반복 201 / 351 | 시간 7[s] | 손실 1.23
# | 에폭 5 |  반복 221 / 351 | 시간 8[s] | 손실 1.22
# | 에폭 5 |  반복 241 / 351 | 시간 8[s] | 손실 1.21
# | 에폭 5 |  반복 261 / 351 | 시간 9[s] | 손실 1.21
# | 에폭 5 |  반복 281 / 351 | 시간 10[s] | 손실 1.21
# | 에폭 5 |  반복 301 / 351 | 시간 11[s] | 손실 1.20
# | 에폭 5 |  반복 321 / 351 | 시간 12[s] | 손실 1.19
# | 에폭 5 |  반복 341 / 351 | 시간 13[s] | 손실 1.18
# Q 77+85
# T 162
# ☒ 145
# ---
# Q 975+164
# T 1139
# ☒ 1168
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 192
# ---
# Q 367+55
# T 422
# ☒ 431
# ---
# Q 600+257
# T 857
# ☒ 895
# ---
# Q 761+292
# T 1053
# ☒ 1015
# ---
# Q 830+597
# T 1427
# ☒ 1493
# ---
# Q 26+838
# T 864
# ☒ 891
# ---
# Q 143+93
# T 236
# ☒ 221
# ---
# 검증 정확도 2.260%
# | 에폭 6 |  반복 1 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 21 / 351 | 시간 0[s] | 손실 1.17
# | 에폭 6 |  반복 41 / 351 | 시간 1[s] | 손실 1.18
# | 에폭 6 |  반복 61 / 351 | 시간 2[s] | 손실 1.17
# | 에폭 6 |  반복 81 / 351 | 시간 2[s] | 손실 1.16
# | 에폭 6 |  반복 101 / 351 | 시간 3[s] | 손실 1.16
# | 에폭 6 |  반복 121 / 351 | 시간 4[s] | 손실 1.16
# | 에폭 6 |  반복 141 / 351 | 시간 4[s] | 손실 1.14
# | 에폭 6 |  반복 161 / 351 | 시간 5[s] | 손실 1.14
# | 에폭 6 |  반복 181 / 351 | 시간 5[s] | 손실 1.13
# | 에폭 6 |  반복 201 / 351 | 시간 6[s] | 손실 1.15
# | 에폭 6 |  반복 221 / 351 | 시간 7[s] | 손실 1.13
# | 에폭 6 |  반복 241 / 351 | 시간 7[s] | 손실 1.13
# | 에폭 6 |  반복 261 / 351 | 시간 8[s] | 손실 1.17
# | 에폭 6 |  반복 281 / 351 | 시간 8[s] | 손실 1.15
# | 에폭 6 |  반복 301 / 351 | 시간 9[s] | 손실 1.11
# | 에폭 6 |  반복 321 / 351 | 시간 10[s] | 손실 1.10
# | 에폭 6 |  반복 341 / 351 | 시간 11[s] | 손실 1.10
# Q 77+85
# T 162
# ☒ 146
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 650
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 412
# ---
# Q 600+257
# T 857
# ☒ 821
# ---
# Q 761+292
# T 1053
# ☒ 1011
# ---
# Q 830+597
# T 1427
# ☒ 1412
# ---
# Q 26+838
# T 864
# ☒ 821
# ---
# Q 143+93
# T 236
# ☒ 207
# ---
# 검증 정확도 1.200%
# | 에폭 7 |  반복 1 / 351 | 시간 0[s] | 손실 1.14
# | 에폭 7 |  반복 21 / 351 | 시간 1[s] | 손실 1.12
# | 에폭 7 |  반복 41 / 351 | 시간 2[s] | 손실 1.11
# | 에폭 7 |  반복 61 / 351 | 시간 2[s] | 손실 1.09
# | 에폭 7 |  반복 81 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 7 |  반복 101 / 351 | 시간 3[s] | 손실 1.08
# | 에폭 7 |  반복 121 / 351 | 시간 4[s] | 손실 1.08
# | 에폭 7 |  반복 141 / 351 | 시간 4[s] | 손실 1.09
# | 에폭 7 |  반복 161 / 351 | 시간 5[s] | 손실 1.08
# | 에폭 7 |  반복 181 / 351 | 시간 5[s] | 손실 1.11
# | 에폭 7 |  반복 201 / 351 | 시간 6[s] | 손실 1.11
# | 에폭 7 |  반복 221 / 351 | 시간 7[s] | 손실 1.11
# | 에폭 7 |  반복 241 / 351 | 시간 7[s] | 손실 1.06
# | 에폭 7 |  반복 261 / 351 | 시간 8[s] | 손실 1.06
# | 에폭 7 |  반복 281 / 351 | 시간 8[s] | 손실 1.05
# | 에폭 7 |  반복 301 / 351 | 시간 9[s] | 손실 1.07
# | 에폭 7 |  반복 321 / 351 | 시간 9[s] | 손실 1.06
# | 에폭 7 |  반복 341 / 351 | 시간 10[s] | 손실 1.04
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1166
# ---
# Q 582+84
# T 666
# ☒ 668
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 867
# ---
# Q 761+292
# T 1053
# ☒ 1058
# ---
# Q 830+597
# T 1427
# ☒ 1444
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 228
# ---
# 검증 정확도 3.900%
# | 에폭 8 |  반복 1 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 8 |  반복 21 / 351 | 시간 0[s] | 손실 1.05
# | 에폭 8 |  반복 41 / 351 | 시간 2[s] | 손실 1.04
# | 에폭 8 |  반복 61 / 351 | 시간 2[s] | 손실 1.04
# | 에폭 8 |  반복 81 / 351 | 시간 3[s] | 손실 1.03
# | 에폭 8 |  반복 101 / 351 | 시간 3[s] | 손실 1.04
# | 에폭 8 |  반복 121 / 351 | 시간 4[s] | 손실 1.03
# | 에폭 8 |  반복 141 / 351 | 시간 4[s] | 손실 1.05
# | 에폭 8 |  반복 161 / 351 | 시간 5[s] | 손실 1.04
# | 에폭 8 |  반복 181 / 351 | 시간 6[s] | 손실 1.02
# | 에폭 8 |  반복 201 / 351 | 시간 7[s] | 손실 1.04
# | 에폭 8 |  반복 221 / 351 | 시간 7[s] | 손실 1.03
# | 에폭 8 |  반복 241 / 351 | 시간 8[s] | 손실 1.02
# | 에폭 8 |  반복 261 / 351 | 시간 8[s] | 손실 1.08
# | 에폭 8 |  반복 281 / 351 | 시간 9[s] | 손실 1.06
# | 에폭 8 |  반복 301 / 351 | 시간 9[s] | 손실 1.05
# | 에폭 8 |  반복 321 / 351 | 시간 10[s] | 손실 1.05
# | 에폭 8 |  반복 341 / 351 | 시간 11[s] | 손실 1.04
# Q 77+85
# T 162
# ☒ 166
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 161
# ---
# Q 367+55
# T 422
# ☒ 411
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1449
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 227
# ---
# 검증 정확도 4.560%
# | 에폭 9 |  반복 1 / 351 | 시간 0[s] | 손실 1.00
# | 에폭 9 |  반복 21 / 351 | 시간 0[s] | 손실 1.01
# | 에폭 9 |  반복 41 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 9 |  반복 61 / 351 | 시간 1[s] | 손실 1.00
# | 에폭 9 |  반복 81 / 351 | 시간 2[s] | 손실 0.99
# | 에폭 9 |  반복 101 / 351 | 시간 3[s] | 손실 0.99
# | 에폭 9 |  반복 121 / 351 | 시간 3[s] | 손실 1.03
# | 에폭 9 |  반복 141 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 9 |  반복 161 / 351 | 시간 4[s] | 손실 0.99
# | 에폭 9 |  반복 181 / 351 | 시간 5[s] | 손실 0.99
# | 에폭 9 |  반복 201 / 351 | 시간 5[s] | 손실 0.99
# | 에폭 9 |  반복 221 / 351 | 시간 6[s] | 손실 0.99
# | 에폭 9 |  반복 241 / 351 | 시간 7[s] | 손실 1.00
# | 에폭 9 |  반복 261 / 351 | 시간 7[s] | 손실 0.98
# | 에폭 9 |  반복 281 / 351 | 시간 8[s] | 손실 0.99
# | 에폭 9 |  반복 301 / 351 | 시간 9[s] | 손실 0.99
# | 에폭 9 |  반복 321 / 351 | 시간 9[s] | 손실 0.99
# | 에폭 9 |  반복 341 / 351 | 시간 10[s] | 손실 0.98
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1128
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 418
# ---
# Q 600+257
# T 857
# ☒ 848
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1428
# ---
# Q 26+838
# T 864
# ☒ 848
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 5.780%
# | 에폭 10 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 10 |  반복 21 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 10 |  반복 41 / 351 | 시간 1[s] | 손실 0.97
# | 에폭 10 |  반복 61 / 351 | 시간 2[s] | 손실 0.98
# | 에폭 10 |  반복 81 / 351 | 시간 2[s] | 손실 0.95
# | 에폭 10 |  반복 101 / 351 | 시간 3[s] | 손실 0.95
# | 에폭 10 |  반복 121 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 10 |  반복 141 / 351 | 시간 4[s] | 손실 0.96
# | 에폭 10 |  반복 161 / 351 | 시간 5[s] | 손실 0.96
# | 에폭 10 |  반복 181 / 351 | 시간 6[s] | 손실 0.96
# | 에폭 10 |  반복 201 / 351 | 시간 6[s] | 손실 0.96
# | 에폭 10 |  반복 221 / 351 | 시간 7[s] | 손실 0.96
# | 에폭 10 |  반복 241 / 351 | 시간 7[s] | 손실 0.99
# | 에폭 10 |  반복 261 / 351 | 시간 8[s] | 손실 0.98
# | 에폭 10 |  반복 281 / 351 | 시간 9[s] | 손실 0.97
# | 에폭 10 |  반복 301 / 351 | 시간 10[s] | 손실 0.97
# | 에폭 10 |  반복 321 / 351 | 시간 10[s] | 손실 0.95
# | 에폭 10 |  반복 341 / 351 | 시간 11[s] | 손실 0.94
# Q 77+85
# T 162
# ☒ 157
# ---
# Q 975+164
# T 1139
# ☒ 1109
# ---
# Q 582+84
# T 666
# ☒ 660
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 409
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1009
# ---
# Q 830+597
# T 1427
# ☒ 1409
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 4.080%
# | 에폭 11 |  반복 1 / 351 | 시간 0[s] | 손실 0.96
# | 에폭 11 |  반복 21 / 351 | 시간 0[s] | 손실 0.98
# | 에폭 11 |  반복 41 / 351 | 시간 1[s] | 손실 0.99
# | 에폭 11 |  반복 61 / 351 | 시간 2[s] | 손실 0.97
# | 에폭 11 |  반복 81 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 11 |  반복 101 / 351 | 시간 3[s] | 손실 0.97
# | 에폭 11 |  반복 121 / 351 | 시간 4[s] | 손실 0.97
# | 에폭 11 |  반복 141 / 351 | 시간 5[s] | 손실 0.95
# | 에폭 11 |  반복 161 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 11 |  반복 181 / 351 | 시간 6[s] | 손실 0.94
# | 에폭 11 |  반복 201 / 351 | 시간 7[s] | 손실 0.93
# | 에폭 11 |  반복 221 / 351 | 시간 7[s] | 손실 0.92
# | 에폭 11 |  반복 241 / 351 | 시간 8[s] | 손실 0.92
# | 에폭 11 |  반복 261 / 351 | 시간 8[s] | 손실 0.94
# | 에폭 11 |  반복 281 / 351 | 시간 9[s] | 손실 0.93
# | 에폭 11 |  반복 301 / 351 | 시간 10[s] | 손실 0.92
# | 에폭 11 |  반복 321 / 351 | 시간 11[s] | 손실 0.93
# | 에폭 11 |  반복 341 / 351 | 시간 11[s] | 손실 0.93
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 661
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 412
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1025
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 228
# ---
# 검증 정확도 5.460%
# | 에폭 12 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 12 |  반복 21 / 351 | 시간 0[s] | 손실 0.93
# | 에폭 12 |  반복 41 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 12 |  반복 61 / 351 | 시간 1[s] | 손실 0.92
# | 에폭 12 |  반복 81 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 12 |  반복 101 / 351 | 시간 2[s] | 손실 0.94
# | 에폭 12 |  반복 121 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 12 |  반복 141 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 12 |  반복 161 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 12 |  반복 181 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 12 |  반복 201 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 12 |  반복 221 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 12 |  반복 241 / 351 | 시간 5[s] | 손실 0.94
# | 에폭 12 |  반복 261 / 351 | 시간 5[s] | 손실 0.93
# | 에폭 12 |  반복 281 / 351 | 시간 6[s] | 손실 0.95
# | 에폭 12 |  반복 301 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 12 |  반복 321 / 351 | 시간 6[s] | 손실 0.91
# | 에폭 12 |  반복 341 / 351 | 시간 7[s] | 손실 0.91
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1129
# ---
# Q 582+84
# T 666
# ☒ 681
# ---
# Q 8+155
# T 163
# ☒ 162
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1420
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 7.180%
# | 에폭 13 |  반복 1 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 13 |  반복 21 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 13 |  반복 41 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 13 |  반복 61 / 351 | 시간 2[s] | 손실 0.90
# | 에폭 13 |  반복 81 / 351 | 시간 2[s] | 손실 0.93
# | 에폭 13 |  반복 101 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 13 |  반복 121 / 351 | 시간 3[s] | 손실 0.93
# | 에폭 13 |  반복 141 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 13 |  반복 161 / 351 | 시간 4[s] | 손실 0.92
# | 에폭 13 |  반복 181 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 13 |  반복 201 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 13 |  반복 221 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 13 |  반복 241 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 13 |  반복 261 / 351 | 시간 6[s] | 손실 0.89
# | 에폭 13 |  반복 281 / 351 | 시간 7[s] | 손실 0.94
# | 에폭 13 |  반복 301 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 13 |  반복 321 / 351 | 시간 8[s] | 손실 0.88
# | 에폭 13 |  반복 341 / 351 | 시간 8[s] | 손실 0.94
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1161
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☑ 163
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1063
# ---
# Q 830+597
# T 1427
# ☒ 1449
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 6.740%
# | 에폭 14 |  반복 1 / 351 | 시간 0[s] | 손실 0.91
# | 에폭 14 |  반복 21 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 14 |  반복 41 / 351 | 시간 0[s] | 손실 0.88
# | 에폭 14 |  반복 61 / 351 | 시간 1[s] | 손실 0.91
# | 에폭 14 |  반복 81 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 14 |  반복 101 / 351 | 시간 1[s] | 손실 0.89
# | 에폭 14 |  반복 121 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 14 |  반복 141 / 351 | 시간 2[s] | 손실 0.92
# | 에폭 14 |  반복 161 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 14 |  반복 181 / 351 | 시간 3[s] | 손실 0.88
# | 에폭 14 |  반복 201 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 14 |  반복 221 / 351 | 시간 4[s] | 손실 0.88
# | 에폭 14 |  반복 241 / 351 | 시간 5[s] | 손실 0.89
# | 에폭 14 |  반복 261 / 351 | 시간 6[s] | 손실 0.88
# | 에폭 14 |  반복 281 / 351 | 시간 7[s] | 손실 0.88
# | 에폭 14 |  반복 301 / 351 | 시간 7[s] | 손실 0.89
# | 에폭 14 |  반복 321 / 351 | 시간 7[s] | 손실 0.90
# | 에폭 14 |  반복 341 / 351 | 시간 8[s] | 손실 0.91
# Q 77+85
# T 162
# ☒ 158
# ---
# Q 975+164
# T 1139
# ☒ 1104
# ---
# Q 582+84
# T 666
# ☒ 655
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☒ 411
# ---
# Q 600+257
# T 857
# ☒ 850
# ---
# Q 761+292
# T 1053
# ☒ 1025
# ---
# Q 830+597
# T 1427
# ☒ 1395
# ---
# Q 26+838
# T 864
# ☒ 855
# ---
# Q 143+93
# T 236
# ☒ 238
# ---
# 검증 정확도 3.240%
# | 에폭 15 |  반복 1 / 351 | 시간 0[s] | 손실 0.94
# | 에폭 15 |  반복 21 / 351 | 시간 0[s] | 손실 0.90
# | 에폭 15 |  반복 41 / 351 | 시간 0[s] | 손실 0.87
# | 에폭 15 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 15 |  반복 81 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 15 |  반복 101 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 15 |  반복 121 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 15 |  반복 141 / 351 | 시간 3[s] | 손실 0.91
# | 에폭 15 |  반복 161 / 351 | 시간 3[s] | 손실 0.90
# | 에폭 15 |  반복 181 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 15 |  반복 201 / 351 | 시간 4[s] | 손실 0.90
# | 에폭 15 |  반복 221 / 351 | 시간 5[s] | 손실 0.87
# | 에폭 15 |  반복 241 / 351 | 시간 5[s] | 손실 0.92
# | 에폭 15 |  반복 261 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 15 |  반복 281 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 15 |  반복 301 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 15 |  반복 321 / 351 | 시간 7[s] | 손실 0.87
# | 에폭 15 |  반복 341 / 351 | 시간 7[s] | 손실 0.87
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1136
# ---
# Q 582+84
# T 666
# ☑ 666
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 862
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 6.540%
# | 에폭 16 |  반복 1 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 16 |  반복 21 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 16 |  반복 41 / 351 | 시간 0[s] | 손실 0.89
# | 에폭 16 |  반복 61 / 351 | 시간 1[s] | 손실 0.90
# | 에폭 16 |  반복 81 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 16 |  반복 101 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 16 |  반복 121 / 351 | 시간 2[s] | 손실 0.89
# | 에폭 16 |  반복 141 / 351 | 시간 3[s] | 손실 0.89
# | 에폭 16 |  반복 161 / 351 | 시간 3[s] | 손실 0.87
# | 에폭 16 |  반복 181 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 16 |  반복 201 / 351 | 시간 4[s] | 손실 0.89
# | 에폭 16 |  반복 221 / 351 | 시간 5[s] | 손실 0.88
# | 에폭 16 |  반복 241 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 16 |  반복 261 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 16 |  반복 281 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 16 |  반복 301 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 16 |  반복 321 / 351 | 시간 7[s] | 손실 0.85
# | 에폭 16 |  반복 341 / 351 | 시간 8[s] | 손실 0.84
# Q 77+85
# T 162
# ☒ 161
# ---
# Q 975+164
# T 1139
# ☒ 1121
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 159
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 868
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 7.640%
# | 에폭 17 |  반복 1 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 17 |  반복 21 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 17 |  반복 41 / 351 | 시간 1[s] | 손실 0.88
# | 에폭 17 |  반복 61 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 17 |  반복 81 / 351 | 시간 2[s] | 손실 0.88
# | 에폭 17 |  반복 101 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 17 |  반복 121 / 351 | 시간 3[s] | 손실 0.85
# | 에폭 17 |  반복 141 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 17 |  반복 161 / 351 | 시간 4[s] | 손실 0.84
# | 에폭 17 |  반복 181 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 17 |  반복 201 / 351 | 시간 5[s] | 손실 0.84
# | 에폭 17 |  반복 221 / 351 | 시간 6[s] | 손실 0.85
# | 에폭 17 |  반복 241 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 17 |  반복 261 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 17 |  반복 281 / 351 | 시간 7[s] | 손실 0.88
# | 에폭 17 |  반복 301 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 17 |  반복 321 / 351 | 시간 8[s] | 손실 0.83
# | 에폭 17 |  반복 341 / 351 | 시간 8[s] | 손실 0.83
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1161
# ---
# Q 582+84
# T 666
# ☒ 658
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 851
# ---
# Q 761+292
# T 1053
# ☒ 1055
# ---
# Q 830+597
# T 1427
# ☒ 1418
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 9.960%
# | 에폭 18 |  반복 1 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 18 |  반복 21 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 18 |  반복 41 / 351 | 시간 0[s] | 손실 0.85
# | 에폭 18 |  반복 61 / 351 | 시간 1[s] | 손실 0.87
# | 에폭 18 |  반복 81 / 351 | 시간 1[s] | 손실 0.83
# | 에폭 18 |  반복 101 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 18 |  반복 121 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 18 |  반복 141 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 18 |  반복 161 / 351 | 시간 3[s] | 손실 0.83
# | 에폭 18 |  반복 181 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 18 |  반복 201 / 351 | 시간 4[s] | 손실 0.85
# | 에폭 18 |  반복 221 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 18 |  반복 241 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 18 |  반복 261 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 18 |  반복 281 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 18 |  반복 301 / 351 | 시간 6[s] | 손실 0.87
# | 에폭 18 |  반복 321 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 18 |  반복 341 / 351 | 시간 7[s] | 손실 0.85
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 672
# ---
# Q 8+155
# T 163
# ☒ 171
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 859
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 9.520%
# | 에폭 19 |  반복 1 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 19 |  반복 21 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 19 |  반복 41 / 351 | 시간 0[s] | 손실 0.84
# | 에폭 19 |  반복 61 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 19 |  반복 81 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 19 |  반복 101 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 19 |  반복 121 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 19 |  반복 141 / 351 | 시간 2[s] | 손실 0.84
# | 에폭 19 |  반복 161 / 351 | 시간 4[s] | 손실 0.83
# | 에폭 19 |  반복 181 / 351 | 시간 6[s] | 손실 0.84
# | 에폭 19 |  반복 201 / 351 | 시간 6[s] | 손실 0.86
# | 에폭 19 |  반복 221 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 19 |  반복 241 / 351 | 시간 7[s] | 손실 0.83
# | 에폭 19 |  반복 261 / 351 | 시간 8[s] | 손실 0.87
# | 에폭 19 |  반복 281 / 351 | 시간 8[s] | 손실 0.84
# | 에폭 19 |  반복 301 / 351 | 시간 9[s] | 손실 0.81
# | 에폭 19 |  반복 321 / 351 | 시간 9[s] | 손실 0.80
# | 에폭 19 |  반복 341 / 351 | 시간 10[s] | 손실 0.82
# Q 77+85
# T 162
# ☒ 164
# ---
# Q 975+164
# T 1139
# ☒ 1126
# ---
# Q 582+84
# T 666
# ☒ 667
# ---
# Q 8+155
# T 163
# ☒ 158
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1404
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 237
# ---
# 검증 정확도 7.840%
# | 에폭 20 |  반복 1 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 20 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 20 |  반복 41 / 351 | 시간 0[s] | 손실 0.82
# | 에폭 20 |  반복 61 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 20 |  반복 81 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 20 |  반복 101 / 351 | 시간 2[s] | 손실 0.86
# | 에폭 20 |  반복 121 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 20 |  반복 141 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 20 |  반복 161 / 351 | 시간 3[s] | 손실 0.84
# | 에폭 20 |  반복 181 / 351 | 시간 4[s] | 손실 0.93
# | 에폭 20 |  반복 201 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 20 |  반복 221 / 351 | 시간 4[s] | 손실 0.91
# | 에폭 20 |  반복 241 / 351 | 시간 5[s] | 손실 0.90
# | 에폭 20 |  반복 261 / 351 | 시간 5[s] | 손실 0.86
# | 에폭 20 |  반복 281 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 20 |  반복 301 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 20 |  반복 321 / 351 | 시간 7[s] | 손실 0.84
# | 에폭 20 |  반복 341 / 351 | 시간 7[s] | 손실 0.82
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1137
# ---
# Q 582+84
# T 666
# ☒ 672
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 419
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1039
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 871
# ---
# Q 143+93
# T 236
# ☒ 232
# ---
# 검증 정확도 10.400%
# | 에폭 21 |  반복 1 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 21 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 21 |  반복 41 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 21 |  반복 61 / 351 | 시간 1[s] | 손실 0.80
# | 에폭 21 |  반복 81 / 351 | 시간 1[s] | 손실 0.84
# | 에폭 21 |  반복 101 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 21 |  반복 121 / 351 | 시간 2[s] | 손실 0.81
# | 에폭 21 |  반복 141 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 21 |  반복 161 / 351 | 시간 3[s] | 손실 0.80
# | 에폭 21 |  반복 181 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 21 |  반복 201 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 21 |  반복 221 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 21 |  반복 241 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 21 |  반복 261 / 351 | 시간 5[s] | 손실 0.83
# | 에폭 21 |  반복 281 / 351 | 시간 5[s] | 손실 0.82
# | 에폭 21 |  반복 301 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 21 |  반복 321 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 21 |  반복 341 / 351 | 시간 7[s] | 손실 0.81
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1160
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 164
# ---
# Q 367+55
# T 422
# ☒ 424
# ---
# Q 600+257
# T 857
# ☒ 866
# ---
# Q 761+292
# T 1053
# ☒ 1063
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 5.600%
# | 에폭 22 |  반복 1 / 351 | 시간 0[s] | 손실 0.86
# | 에폭 22 |  반복 21 / 351 | 시간 0[s] | 손실 0.81
# | 에폭 22 |  반복 41 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 22 |  반복 61 / 351 | 시간 1[s] | 손실 0.82
# | 에폭 22 |  반복 81 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 22 |  반복 101 / 351 | 시간 2[s] | 손실 0.82
# | 에폭 22 |  반복 121 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 22 |  반복 141 / 351 | 시간 4[s] | 손실 0.81
# | 에폭 22 |  반복 161 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 22 |  반복 181 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 22 |  반복 201 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 22 |  반복 221 / 351 | 시간 8[s] | 손실 0.79
# | 에폭 22 |  반복 241 / 351 | 시간 8[s] | 손실 0.81
# | 에폭 22 |  반복 261 / 351 | 시간 9[s] | 손실 0.81
# | 에폭 22 |  반복 281 / 351 | 시간 10[s] | 손실 0.79
# | 에폭 22 |  반복 301 / 351 | 시간 11[s] | 손실 0.81
# | 에폭 22 |  반복 321 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 22 |  반복 341 / 351 | 시간 12[s] | 손실 0.79
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1130
# ---
# Q 582+84
# T 666
# ☒ 655
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☒ 427
# ---
# Q 600+257
# T 857
# ☒ 850
# ---
# Q 761+292
# T 1053
# ☒ 1037
# ---
# Q 830+597
# T 1427
# ☒ 1430
# ---
# Q 26+838
# T 864
# ☒ 867
# ---
# Q 143+93
# T 236
# ☒ 242
# ---
# 검증 정확도 8.200%
# | 에폭 23 |  반복 1 / 351 | 시간 0[s] | 손실 0.79
# | 에폭 23 |  반복 21 / 351 | 시간 0[s] | 손실 0.80
# | 에폭 23 |  반복 41 / 351 | 시간 1[s] | 손실 0.78
# | 에폭 23 |  반복 61 / 351 | 시간 2[s] | 손실 0.83
# | 에폭 23 |  반복 81 / 351 | 시간 3[s] | 손실 0.82
# | 에폭 23 |  반복 101 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 23 |  반복 121 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 23 |  반복 141 / 351 | 시간 5[s] | 손실 0.81
# | 에폭 23 |  반복 161 / 351 | 시간 6[s] | 손실 0.82
# | 에폭 23 |  반복 181 / 351 | 시간 7[s] | 손실 0.82
# | 에폭 23 |  반복 201 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 23 |  반복 221 / 351 | 시간 8[s] | 손실 0.82
# | 에폭 23 |  반복 241 / 351 | 시간 9[s] | 손실 0.81
# | 에폭 23 |  반복 261 / 351 | 시간 9[s] | 손실 0.80
# | 에폭 23 |  반복 281 / 351 | 시간 10[s] | 손실 0.84
# | 에폭 23 |  반복 301 / 351 | 시간 11[s] | 손실 0.83
# | 에폭 23 |  반복 321 / 351 | 시간 11[s] | 손실 0.82
# | 에폭 23 |  반복 341 / 351 | 시간 12[s] | 손실 0.80
# Q 77+85
# T 162
# ☒ 160
# ---
# Q 975+164
# T 1139
# ☒ 1133
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 165
# ---
# Q 367+55
# T 422
# ☑ 422
# ---
# Q 600+257
# T 857
# ☒ 846
# ---
# Q 761+292
# T 1053
# ☒ 1038
# ---
# Q 830+597
# T 1427
# ☒ 1415
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☒ 239
# ---
# 검증 정확도 8.880%
# | 에폭 24 |  반복 1 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 24 |  반복 21 / 351 | 시간 0[s] | 손실 0.78
# | 에폭 24 |  반복 41 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 24 |  반복 61 / 351 | 시간 1[s] | 손실 0.76
# | 에폭 24 |  반복 81 / 351 | 시간 1[s] | 손실 0.77
# | 에폭 24 |  반복 101 / 351 | 시간 2[s] | 손실 0.78
# | 에폭 24 |  반복 121 / 351 | 시간 2[s] | 손실 0.77
# | 에폭 24 |  반복 141 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 24 |  반복 161 / 351 | 시간 3[s] | 손실 0.79
# | 에폭 24 |  반복 181 / 351 | 시간 4[s] | 손실 0.78
# | 에폭 24 |  반복 201 / 351 | 시간 4[s] | 손실 0.80
# | 에폭 24 |  반복 221 / 351 | 시간 5[s] | 손실 0.78
# | 에폭 24 |  반복 241 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 24 |  반복 261 / 351 | 시간 6[s] | 손실 0.79
# | 에폭 24 |  반복 281 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 24 |  반복 301 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 24 |  반복 321 / 351 | 시간 7[s] | 손실 0.79
# | 에폭 24 |  반복 341 / 351 | 시간 8[s] | 손실 0.78
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1127
# ---
# Q 582+84
# T 666
# ☒ 665
# ---
# Q 8+155
# T 163
# ☒ 157
# ---
# Q 367+55
# T 422
# ☒ 417
# ---
# Q 600+257
# T 857
# ☒ 849
# ---
# Q 761+292
# T 1053
# ☒ 1037
# ---
# Q 830+597
# T 1427
# ☒ 1424
# ---
# Q 26+838
# T 864
# ☒ 859
# ---
# Q 143+93
# T 236
# ☒ 229
# ---
# 검증 정확도 8.360%
# | 에폭 25 |  반복 1 / 351 | 시간 0[s] | 손실 0.77
# | 에폭 25 |  반복 21 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 25 |  반복 41 / 351 | 시간 0[s] | 손실 0.76
# | 에폭 25 |  반복 61 / 351 | 시간 1[s] | 손실 0.76
# | 에폭 25 |  반복 81 / 351 | 시간 1[s] | 손실 0.75
# | 에폭 25 |  반복 101 / 351 | 시간 2[s] | 손실 0.76
# | 에폭 25 |  반복 121 / 351 | 시간 3[s] | 손실 0.76
# | 에폭 25 |  반복 141 / 351 | 시간 3[s] | 손실 0.77
# | 에폭 25 |  반복 161 / 351 | 시간 4[s] | 손실 0.75
# | 에폭 25 |  반복 181 / 351 | 시간 4[s] | 손실 0.76
# | 에폭 25 |  반복 201 / 351 | 시간 4[s] | 손실 0.76
# | 에폭 25 |  반복 221 / 351 | 시간 5[s] | 손실 0.77
# | 에폭 25 |  반복 241 / 351 | 시간 6[s] | 손실 0.81
# | 에폭 25 |  반복 261 / 351 | 시간 7[s] | 손실 0.80
# | 에폭 25 |  반복 281 / 351 | 시간 7[s] | 손실 0.78
# | 에폭 25 |  반복 301 / 351 | 시간 8[s] | 손실 0.77
# | 에폭 25 |  반복 321 / 351 | 시간 9[s] | 손실 0.77
# | 에폭 25 |  반복 341 / 351 | 시간 10[s] | 손실 0.75
# Q 77+85
# T 162
# ☑ 162
# ---
# Q 975+164
# T 1139
# ☒ 1138
# ---
# Q 582+84
# T 666
# ☒ 662
# ---
# Q 8+155
# T 163
# ☒ 160
# ---
# Q 367+55
# T 422
# ☒ 426
# ---
# Q 600+257
# T 857
# ☒ 856
# ---
# Q 761+292
# T 1053
# ☒ 1049
# ---
# Q 830+597
# T 1427
# ☒ 1429
# ---
# Q 26+838
# T 864
# ☒ 861
# ---
# Q 143+93
# T 236
# ☑ 236
# ---
# 검증 정확도 12.520%
# /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50640 (\N{HANGUL SYLLABLE E}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54253 (\N{HANGUL SYLLABLE POG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51221 (\N{HANGUL SYLLABLE JEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 54869 (\N{HANGUL SYLLABLE HWAG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /opt/miniconda3/envs/hanghae99/lib/python3.10/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 46020 (\N{HANGUL SYLLABLE DO}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
